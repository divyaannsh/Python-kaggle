# %%
#import library
pip install kaggle
# Out:
# ...
#      ---------------------------------------- 0.0/82.7 kB ? eta -:--:--
#      ---------------------------------------- 82.7/82.7 kB 4.8 MB/s eta 0:00:00
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# ...
#      ---------------------------------------- 0.0/57.7 kB ? eta -:--:--
#      ---------------------------------------- 57.7/57.7 kB 1.5 MB/s eta 0:00:00
# ...
#    ---------------------------------------- 0.0/78.5 kB ? eta -:--:--
#    ---------------------------------------- 78.5/78.5 kB 4.3 MB/s eta 0:00:00
# ...
#    ---------------------------------------- 0.0/78.2 kB ? eta -:--:--
#    ---------------------------------------- 78.2/78.2 kB ? eta 0:00:00
# ...

# %%
import subprocess

# Run the Kaggle CLI command to download the file 
subprocess.run([
    "kaggle", 
    "datasets", 
    "download", 
    "ankitbansal06/retail-orders", 
    "-f", 
    "orders.csv"
])
# Out:
# CompletedProcess(args=['kaggle', 'datasets', 'download', 'ankitbansal06/retail-orders', '-f', 'orders.csv'], returncode=0)

# %%
#download dataset using kagg'e api
import zipfile
zip_ref = zipfile.ZipFile('orders.csv.zip')
zip_ref.extractall()
zip_ref.close()

# %%
#read data from the file and handle null values
import pandas as pd
df =pd.read_csv('orders.csv')
df.head(20)
# Out:
#     Order Id  Order Date       Ship Mode      Segment        Country  \
# 0          1  2023-03-01    Second Class     Consumer  United States
# 1          2  2023-08-15    Second Class     Consumer  United States
# 2          3  2023-01-10    Second Class    Corporate  United States
# 3          4  2022-06-18  Standard Class     Consumer  United States
# 4          5  2022-07-13  Standard Class     Consumer  United States
# 5          6  2022-03-13   Not Available     Consumer  United States
# 6          7  2022-12-28  Standard Class     Consumer  United States
# 7          8  2022-01-25  Standard Class     Consumer  United States
# 8          9  2023-03-23   Not Available     Consumer  United States
# 9         10  2023-05-16  Standard Class     Consumer  United States
# 10        11  2023-03-31   Not Available     Consumer  United States
# 11        12  2023-12-25   Not Available     Consumer  United States
# 12        13  2022-02-11  Standard Class     Consumer  United States
# ...

# %%
import pandas as pd
df =pd.read_csv('orders.csv',na_values=['Not Available', 'Unknown'])
df.head(20)
df['Ship Mode'].unique()
# Out:
# array(['Second Class', 'Standard Class', nan, 'unknown', 'First Class',
#        'Same Day'], dtype=object)

# %%
#rename columns names make them lower case and replace space with underscoire
df.rename(columns={'Order id':'order_id','City':'city'})
# Out:
#       Order Id  Order Date       Ship Mode    Segment        Country  \
# 0            1  2023-03-01    Second Class   Consumer  United States
# 1            2  2023-08-15    Second Class   Consumer  United States
# 2            3  2023-01-10    Second Class  Corporate  United States
# 3            4  2022-06-18  Standard Class   Consumer  United States
# 4            5  2022-07-13  Standard Class   Consumer  United States
# ...        ...         ...             ...        ...            ...
# 9989      9990  2023-02-18    Second Class   Consumer  United States
# 9990      9991  2023-03-17  Standard Class   Consumer  United States
# 9991      9992  2022-08-07  Standard Class   Consumer  United States
# 9992      9993  2022-11-19  Standard Class   Consumer  United States
# 9993      9994  2022-07-17    Second Class   Consumer  United States
#
#                  city       State  Postal Code Region         Category  \
# ...

# %%
#derive new columns discount sale price and profit

df['discount'] =df['List Price']*df['Discount Percent']*.01
df
# Out:
#       Order Id  Order Date       Ship Mode    Segment        Country  \
# 0            1  2023-03-01    Second Class   Consumer  United States
# 1            2  2023-08-15    Second Class   Consumer  United States
# 2            3  2023-01-10    Second Class  Corporate  United States
# 3            4  2022-06-18  Standard Class   Consumer  United States
# 4            5  2022-07-13  Standard Class   Consumer  United States
# ...        ...         ...             ...        ...            ...
# 9989      9990  2023-02-18    Second Class   Consumer  United States
# 9990      9991  2023-03-17  Standard Class   Consumer  United States
# 9991      9992  2022-08-07  Standard Class   Consumer  United States
# 9992      9993  2022-11-19  Standard Class   Consumer  United States
# 9993      9994  2022-07-17    Second Class   Consumer  United States
#
#                  City       State  Postal Code Region         Category  \
# ...

# %%
import pandas as pd

# Check the data types in the DataFrame
print(df.dtypes)

# Convert 'order_date' column to datetime
#df['order_date'] = pd.to_datetime(df['order_date'], format="%Y-%m-%d")
# Out:
# Order Id              int64
# Order Date           object
# Ship Mode            object
# Segment              object
# Country              object
# City                 object
# State                object
# Postal Code           int64
# Region               object
# Category             object
# Sub Category         object
# Product Id           object
# cost price            int64
# List Price            int64
# Quantity              int64
# Discount Percent      int64
# discount            float64
# dtype: object

# %%
import sqlalchemy as sal
# Out:
#   Cell In[24], line 1
#     pip install sqlalchemy
#         ^
# SyntaxError: invalid syntax

# %%
pip install sqlalchemy
# Out:
# ...
#
# ...
#   Using cached typing_extensions-4.12.2-py3-none-any.whl.metadata (3.0 kB)
# ...
#    ---------------------------------------- 0.0/2.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/2.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/2.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/2.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/2.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/2.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/2.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/2.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/2.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/2.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/2.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/2.1 MB ? eta -:--:--
# ...

# %%
import pandas as pd
import sqlalchemy as sal  # Ensure you import SQLAlchemy as 'sal'

# Create the SQL Server engine
engine = sal.create_engine('mssql://DESKTOP-K05DU0I/master?driver=ODBC+Driver+17+for+SQL+Server')

# Connect to the database
conn = engine.connect()

# Load your DataFrame (example)
# df = pd.read_csv("your_file.csv")  # Example of loading a DataFrame

# Replace data in an existing SQL table
df.to_sql('df_orders', con=conn, if_exists='replace', index=False)

# Close the connection
conn.close()

# %%
import pandas as pd

# Assuming df is your DataFrame
df.columns = df.columns.str.replace(' ', '_')

# Display the updated column names
print(df.columns)
# Out:
# Index(['Order_Id', 'Order_Date', 'Ship_Mode', 'Segment', 'Country', 'City',
#        'State', 'Postal_Code', 'Region', 'Category', 'Sub_Category',
#        'Product_Id', 'cost_price', 'List_Price', 'Quantity',
#        'Discount_Percent', 'discount'],
#       dtype='object')
